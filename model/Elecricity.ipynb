# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("data.csv")
dataset
# Out:
#               States Regions   latitude  longitude       Dates  Usage
# 0             Punjab      NR  31.519974  75.980003  02-01-2019  119.9
# 1            Haryana      NR  28.450006  77.019991  02-01-2019  130.3
# 2          Rajasthan      NR  26.449999  74.639981  02-01-2019  234.1
# 3              Delhi      NR  28.669993  77.230004  02-01-2019   85.8
# 4      Uttar Pradesh      NR  27.599981  78.050006  02-01-2019  313.9
# ...              ...     ...        ...        ...         ...    ...
# 16594        Manipur     NER  24.799971  93.950017  05-12-2020    2.5
# 16595      Meghalaya     NER  25.570492  91.880014  05-12-2020    5.8
# 16596        Mizoram     NER  23.710399  92.720015  05-12-2020    1.6
# 16597       Nagaland     NER  25.666998  94.116570  05-12-2020    2.1
# 16598        Tripura     NER  23.835404  91.279999  05-12-2020    3.3
#
# [16599 rows x 6 columns]

# %%
df = pd.DataFrame(dataset)
df
# Out:
#               States Regions   latitude  longitude       Dates  Usage
# 0             Punjab      NR  31.519974  75.980003  02-01-2019  119.9
# 1            Haryana      NR  28.450006  77.019991  02-01-2019  130.3
# 2          Rajasthan      NR  26.449999  74.639981  02-01-2019  234.1
# 3              Delhi      NR  28.669993  77.230004  02-01-2019   85.8
# 4      Uttar Pradesh      NR  27.599981  78.050006  02-01-2019  313.9
# ...              ...     ...        ...        ...         ...    ...
# 16594        Manipur     NER  24.799971  93.950017  05-12-2020    2.5
# 16595      Meghalaya     NER  25.570492  91.880014  05-12-2020    5.8
# 16596        Mizoram     NER  23.710399  92.720015  05-12-2020    1.6
# 16597       Nagaland     NER  25.666998  94.116570  05-12-2020    2.1
# 16598        Tripura     NER  23.835404  91.279999  05-12-2020    3.3
#
# [16599 rows x 6 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16599 entries, 0 to 16598
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   States     16599 non-null  object
#  1   Regions    16599 non-null  object
#  2   latitude   16599 non-null  float64
#  3   longitude  16599 non-null  float64
#  4   Dates      16599 non-null  object
#  5   Usage      16599 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 778.2+ KB

# %%
df[['Day','Month','Year']] = df.Dates.str.split("-", expand = True)
df
# Out:
#               States Regions   latitude  longitude       Dates  Usage Day  \
# 0             Punjab      NR  31.519974  75.980003  02-01-2019  119.9  02
# 1            Haryana      NR  28.450006  77.019991  02-01-2019  130.3  02
# 2          Rajasthan      NR  26.449999  74.639981  02-01-2019  234.1  02
# 3              Delhi      NR  28.669993  77.230004  02-01-2019   85.8  02
# 4      Uttar Pradesh      NR  27.599981  78.050006  02-01-2019  313.9  02
# ...              ...     ...        ...        ...         ...    ...  ..
# 16594        Manipur     NER  24.799971  93.950017  05-12-2020    2.5  05
# 16595      Meghalaya     NER  25.570492  91.880014  05-12-2020    5.8  05
# 16596        Mizoram     NER  23.710399  92.720015  05-12-2020    1.6  05
# 16597       Nagaland     NER  25.666998  94.116570  05-12-2020    2.1  05
# 16598        Tripura     NER  23.835404  91.279999  05-12-2020    3.3  05
#
#       Month  Year
# 0        01  2019
# 1        01  2019
# 2        01  2019
# 3        01  2019
# 4        01  2019
# ...     ...   ...
# 16594    12  2020
# 16595    12  2020
# 16596    12  2020
# 16597    12  2020
# 16598    12  2020
#
# [16599 rows x 9 columns]

# %%
df['Year'] = df['Year'].str.replace(' 00:00', '')
df
# Out:
#               States Regions   latitude  longitude       Dates  Usage Day  \
# 0             Punjab      NR  31.519974  75.980003  02-01-2019  119.9  02
# 1            Haryana      NR  28.450006  77.019991  02-01-2019  130.3  02
# 2          Rajasthan      NR  26.449999  74.639981  02-01-2019  234.1  02
# 3              Delhi      NR  28.669993  77.230004  02-01-2019   85.8  02
# 4      Uttar Pradesh      NR  27.599981  78.050006  02-01-2019  313.9  02
# ...              ...     ...        ...        ...         ...    ...  ..
# 16594        Manipur     NER  24.799971  93.950017  05-12-2020    2.5  05
# 16595      Meghalaya     NER  25.570492  91.880014  05-12-2020    5.8  05
# 16596        Mizoram     NER  23.710399  92.720015  05-12-2020    1.6  05
# 16597       Nagaland     NER  25.666998  94.116570  05-12-2020    2.1  05
# 16598        Tripura     NER  23.835404  91.279999  05-12-2020    3.3  05
#
#       Month  Year
# 0        01  2019
# 1        01  2019
# 2        01  2019
# 3        01  2019
# 4        01  2019
# ...     ...   ...
# 16594    12  2020
# 16595    12  2020
# 16596    12  2020
# 16597    12  2020
# 16598    12  2020
#
# [16599 rows x 9 columns]

# %%
df.drop(['Dates'], axis=1)
# Out:
#               States Regions   latitude  longitude  Usage Day Month  Year
# 0             Punjab      NR  31.519974  75.980003  119.9  02    01  2019
# 1            Haryana      NR  28.450006  77.019991  130.3  02    01  2019
# 2          Rajasthan      NR  26.449999  74.639981  234.1  02    01  2019
# 3              Delhi      NR  28.669993  77.230004   85.8  02    01  2019
# 4      Uttar Pradesh      NR  27.599981  78.050006  313.9  02    01  2019
# ...              ...     ...        ...        ...    ...  ..   ...   ...
# 16594        Manipur     NER  24.799971  93.950017    2.5  05    12  2020
# 16595      Meghalaya     NER  25.570492  91.880014    5.8  05    12  2020
# 16596        Mizoram     NER  23.710399  92.720015    1.6  05    12  2020
# 16597       Nagaland     NER  25.666998  94.116570    2.1  05    12  2020
# 16598        Tripura     NER  23.835404  91.279999    3.3  05    12  2020
#
# [16599 rows x 8 columns]

# %%
def get_state_usage():
    # filtered_df = df[(df['States'] == state) & (df['Year'] == year)]
    # filtered_df.sort_values("Month",ascending=False)
    usage_sum =  df.groupby('States')['Usage'].sum().reset_index()
    sorted_usage = usage_sum.sort_values('Usage', ascending=False).head(5)
    json_data = sorted_usage.to_json(orient='records')
    return json_data

k = get_state_usage()
k
# Out:
# '[{"States":"Maharashtra","Usage":217079.8},{"States":"Gujarat","Usage":162488.9},{"States":"Uttar Pradesh","Usage":157960.3},{"States":"Tamil Nadu","Usage":151271.5},{"States":"Rajasthan","Usage":109877.0}]'

# %%
from sklearn.model_selection import train_test_split
x = df[['States','Month','Day']]
y = df['Usage']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
train_data = x_train.join(y_train)

# %%
test_data = x_test.join(y_test)

# %%
train_data
# Out:
#                  States Month Day  Usage
# 8249            Tripura    09  10    3.9
# 9250            Gujarat    10  12  378.9
# 9940    Jammu & Kashmir    11  02   40.4
# 4140     Andhra Pradesh    05  11  160.0
# 9647     Madhya Pradesh    10  24  229.3
# ...                 ...   ...  ..    ...
# 1062   Himachal Pardesh    02  04   12.4
# 3394            Manipur    04  17    2.6
# 3998        Uttarakhand    05  07   40.4
# 3876     Andhra Pradesh    05  03  170.1
# 10073        Chandigarh    11  06    2.9
#
# [13279 rows x 4 columns]

# %%
test_data=test_data.join(pd.get_dummies(test_data.States)).drop(['States'],axis=1)

# %%
train_data=train_data.join(pd.get_dummies(train_data.States)).drop(['States'],axis=1)

# %%
plt.figure(figsize=(30,10))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from matplotlib import style

fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))

style.use('ggplot')

sns.lineplot(x=dataset["States"], y=dataset["Usage"], data=df)
sns.set(rc={'figure.figsize':(15,13)})

plt.title("Electricity consumption in Year 2019-2020")
plt.xlabel("States")
plt.ylabel("Usage")
plt.grid(True)
plt.legend()

for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)


plt.title("Electricity Consumption According to States")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 1.0, 'Electricity Consumption According to States')

# %%
x_train=x_train.join(pd.get_dummies(x_train.States)).drop(['States'],axis=1)

# %%
from sklearn.linear_model import LinearRegression
x_train, y_train = train_data.drop(['Usage'],axis=1),train_data['Usage']
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_data
# Out:
#       Month Day  Usage  Andhra Pradesh  Arunachal Pradesh  Assam  Bihar  \
# 1935     03  03   76.8           False              False  False   True
# 14553    04  20  105.2           False              False  False  False
# 8357     09  14    4.7           False              False  False  False
# 15264    05  18   74.3           False              False  False  False
# 12250    01  20   40.8           False              False  False  False
# ...     ...  ..    ...             ...                ...    ...    ...
# 3595     04  23    2.2           False              False  False  False
# 11089    12  09  110.5           False              False  False  False
# 12097    01  15  340.6           False              False  False  False
# 1293     02  11   27.1           False              False  False  False
# 4860     06  03   74.1           False              False  False  False
#
#        Chandigarh  Chhattisgarh  Dadra & Nagar Haveli  ...  Pondy  Punjab  \
# 1935        False         False                 False  ...  False   False
# 14553       False         False                 False  ...  False    True
# 8357         True         False                 False  ...  False   False
# 15264       False         False                 False  ...  False   False
# 12250       False         False                 False  ...  False   False
# ...           ...           ...                   ...  ...    ...     ...
# 3595        False         False                 False  ...  False   False
# 11089       False         False                 False  ...  False   False
# 12097       False         False                 False  ...  False   False
# 1293        False         False                 False  ...  False   False
# 4860        False          True                 False  ...  False   False
#
#        Rajasthan  Sikkim  Tamil Nadu  Telangana  Tripura  Uttar Pradesh  \
# 1935       False   False       False      False    False          False
# 14553      False   False       False      False    False          False
# 8357       False   False       False      False    False          False
# 15264      False   False       False      False    False          False
# 12250      False   False       False      False    False          False
# ...          ...     ...         ...        ...      ...            ...
# 3595       False   False       False      False    False          False
# 11089      False   False       False      False    False          False
# 12097      False   False        True      False    False          False
# 1293       False   False       False      False    False          False
# 4860       False   False       False      False    False          False
#
#        Uttarakhand  West Bengal
# 1935         False        False
# 14553        False        False
# 8357         False        False
# 15264        False        False
# 12250        False        False
# ...            ...          ...
# 3595         False        False
# 11089        False        False
# 12097        False        False
# 1293         False        False
# 4860         False        False
#
# [3320 rows x 36 columns]

# %%
x_test,y_test = test_data.drop(['Usage'],axis=1),test_data['Usage']

# %%
reg.fit(x_train,y_train)
reg.score(x_test,y_test)
# Out:
# 0.9538939611666957

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5,test_size=0.2, random_state=0)

cross_val_score(LinearRegression(),x_test,y_test,cv=cv)
# Out:
# array([0.94420329, 0.96007577, 0.95874778, 0.95260407, 0.95175896])

# %%
x_train.columns
# Out:
# Index(['Month', 'Day', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chandigarh', 'Chhattisgarh', 'Dadra & Nagar Haveli', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pardesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Pondy',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype='object')

# %%
x_test.head()
# Out:
#       Month Day  Andhra Pradesh  Arunachal Pradesh  Assam  Bihar  Chandigarh  \
# 1935     03  03           False              False  False   True       False
# 14553    04  20           False              False  False  False       False
# 8357     09  14           False              False  False  False        True
# 15264    05  18           False              False  False  False       False
# 12250    01  20           False              False  False  False       False
#
#        Chhattisgarh  Dadra & Nagar Haveli  Delhi  ...  Pondy  Punjab  \
# 1935          False                 False  False  ...  False   False
# 14553         False                 False  False  ...  False    True
# 8357          False                 False  False  ...  False   False
# 15264         False                 False  False  ...  False   False
# 12250         False                 False  False  ...  False   False
#
#        Rajasthan  Sikkim  Tamil Nadu  Telangana  Tripura  Uttar Pradesh  \
# 1935       False   False       False      False    False          False
# 14553      False   False       False      False    False          False
# 8357       False   False       False      False    False          False
# 15264      False   False       False      False    False          False
# 12250      False   False       False      False    False          False
#
#        Uttarakhand  West Bengal
# 1935         False        False
# 14553        False        False
# 8357         False        False
# 15264        False        False
# 12250        False        False
#
# [5 rows x 35 columns]

# %%
def predict_consumption(State,Month,Day):
    state_index = np.where(x_train.columns==State)[0][0]
    k = np.zeros(len(x_train.columns))
    k[0] = Month
    k[1] = Day
    if state_index >=0 :
        k[state_index] = 1
        return reg.predict([k])[0]

# %%
predict_consumption("Karnataka",5,30)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 214.33203125

# %%
reg.predict(x_test[3:4])
# Out:
# array([72.46679688])

# %%
x_test[4:5].to_numpy()
# Out:
# array([['01', '20', False, False, False, False, False, False, False,
#         False, False, False, False, False, True, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False]],
#       dtype=object)

# %%
x_test[4:5].to_numpy()
# Out:
# array([['01', '20', False, False, False, False, False, False, False,
#         False, False, False, False, False, True, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False]],
#       dtype=object)

# %%
import pickle
with open("electricity_consumption.pickle","wb") as f:
    pickle.dump(reg,f)

# %%
import json
columns = {
    'data_columns' : [col for col in x_train.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
